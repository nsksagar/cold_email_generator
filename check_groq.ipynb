# %%
from langchain_groq import ChatGroq

# %%
with open('api_key.txt', 'r') as file:

    my_api_key = file.read().strip()

# %%
llm = ChatGroq(
    model= "llama-3.3-70b-versatile",
    api_key = my_api_key,
    temperature=0,
)

# %%
response = llm.invoke('which country is located between Canada and Mexico ? ')

print(response.content)
# Out:
# The country located between Canada and Mexico is the United States of America (USA).
